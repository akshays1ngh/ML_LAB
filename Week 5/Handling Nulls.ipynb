# %%
import pandas as pd

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
#count number of null values in each column
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#sum of all the  null values in the dataset
df.isnull().sum().sum()
# Out:
# 6201

# %%
#replacing null values with 0
df1=df.fillna(value='abc')
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft bath balcony   price
# 0  Coomee        1056  2.0     1.0   39.07
# 1  Theanmp       2600  5.0     3.0  120.00
# 2      abc       1440  2.0     3.0   62.00
# 3  Soiewre       1521  3.0     1.0   95.00
# 4      abc       1200  2.0     1.0   51.00

# %%
#verifying
df1.isnull().sum().sum()
# Out:
# 0

# %%
#Filling null values with previous values
df2=df.fillna(method='pad')
df2.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2  Theanmp       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4  Soiewre       1200   2.0      1.0   51.00

# %%
#verifying
df2.isnull().sum().sum()
# Out:
# 0

# %%
#filling null values with the next values rowwise
#bfill--> backward fill

df3=df.fillna(method='bfill')
df3.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2  Soiewre       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4  DuenaTa       1200   2.0      1.0   51.00

# %%
#filling null values with previous column values

df4=df.fillna(method='pad',axis=1)
df4.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft bath balcony  price
# 0  Coomee        1056  2.0     1.0  39.07
# 1  Theanmp       2600  5.0     3.0  120.0
# 2    3 BHK       1440  2.0     3.0   62.0
# 3  Soiewre       1521  3.0     1.0   95.0
# 4    2 BHK       1200  2.0     1.0   51.0

# %%
#filling null values with the next values columnwise
#bfill--> backward fill

df5=df.fillna(method='bfill',axis=1)
df5.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft bath balcony  price
# 0  Coomee        1056  2.0     1.0  39.07
# 1  Theanmp       2600  5.0     3.0  120.0
# 2     1440       1440  2.0     3.0   62.0
# 3  Soiewre       1521  3.0     1.0   95.0
# 4     1200       1200  2.0     1.0   51.0

# %%
#filiing the null values with specific data values

df6=df.fillna({'society': 'Konoha','size':'Choji'})
df6.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2   Konoha       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4   Konoha       1200   2.0      1.0   51.00

# %%
s=0
for i in df['balcony']:
    if(i=='NaN'):
        continue
    else:
        s=s+i
s
# Out:
# nan

# %%
#total rows= 13320
#null values=609
#non null values= 12711

#make 2 dataframes on null and non-null values

# %%
#filling values with max of a column

df7=df.fillna(value=df['balcony'].max())
df7.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      3.0       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      3.0       1200   2.0      1.0   51.00

# %%
#drop rows having null values
df8=df['location'].dropna()
df8.shape
# Out:
# (13319,)

# %%
#LURKING VARIABLES

# %%
#Dropping the rows that contain NULL values using the parameter how.
#how can take 2 values: 'any' or 'all'
#any: if any row conatins null drop the row
#all:: if all rows conmtains null then drop the row

df9=df.dropna(how='all')
df9.shape
# Out:
# (13320, 9)

# %%
#count of null values row-wise
df.isna().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 13315    0
# 13316    2
# 13317    0
# 13318    0
# 13319    1
# Length: 13320, dtype: int64

# %%
#df.replace()
#all the NaN values are replaced by the value.

import numpy as np
df10=df.replace(to_replace=np.nan,value=99999)
df10.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2    99999       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4    99999       1200   2.0      1.0   51.00

# %%
#replacing a value with different value
df11=df.replace(to_replace=18.0,value=3.0)
df11.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00
